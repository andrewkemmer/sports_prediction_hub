# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewkemmer/sports_prediction_hub/blob/main/colab_daily_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# 1. Check if the authenticated folder is visible, or use standard terminal cloning
if not os.path.exists('/content/sports_prediction_hub'):
    # !git clone https://github.com

# 2. Step precisely into your engine workspace subfolder
# %cd /content/sports_prediction_hub/mlb_streamlit

# 3. Pull any fresh structural edits pushed by your AI Agent
# !git pull origin main

# 4. Install your machine learning libraries headlessly
print("📥 Installing machine learning dependencies...")
# !pip install -q xgboost lightgbm scikit-learn pandas numpy requests streamlit

# 5. Run the automated model loop script
print("⚾ Warming model architectures and calculation loops...")
# !python3 scripts/warm_cache.py --force
# Out:
# /content/sports_prediction_hub/mlb_streamlit
# From https://github.com/andrewkemmer/sports_prediction_hub
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# 📥 Installing machine learning dependencies...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 94.2 MB/s eta 0:00:00
# ⚾ Warming model architectures and calculation loops...
# Warming cache (force_full=True)…
#   [  4%] Reading cached data: Loading previously stored games…
#   [ 12%] Fetching fresh games: Loading recent results + upcoming window…
#   [ 20%] Fetching schedule: Loaded 148 fresh game(s)…
#   [ 24%] Fetching game data: Loading pitcher/team logs, lineups & injuries…
#   [ 22%] Checking for changes: Comparing data fingerprint…
#   [ 24%] Fetching game data: Loading pitcher/team logs, lineups & injuries…
#   [ 40%] Game data loaded: Pitcher 164 · team 30 · lineups 1 · IL 30 teams
# ...

# %%
# 1. Stay at the main repository root directory
# %cd /content/sports_prediction_hub

# 2. Force-stage the exact file assets that were blocked by .gitignore
print("📦 Overriding ignore rules to track true model assets...")
# !git add -f mlb_streamlit/walk_forward_selection.json 2>/dev/null || true
# !git add -f walk_forward_selection.json 2>/dev/null || true
# !git add -f mlb_streamlit/cache/_pool_cache/*

# 3. Commit and push the payload directly to your tracking branch
print("📤 Syncing deployment data to GitHub...")
# !git commit -m "fix: force push version 13 model matrices bypassing gitignore rules"
# !git push origin main

print("🏁 Perfect Sync! Your files are safely tracked in your repository.")
# Out:
# /content/sports_prediction_hub
# 📦 Overriding ignore rules to track true model assets...
# 📤 Syncing deployment data to GitHub...
# [main e6d5bfb] fix: force push version 13 model matrices bypassing gitignore rules
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 mlb_streamlit/cache/_pool_cache/56/56e72e55bfd5f512f2ad23eb321374e1fb96eb4414d019e2ba68128915fe9c3b.json.gz
#  create mode 100644 mlb_streamlit/cache/_pool_cache/f8/f8266eb43e44cb2ceedd3ba1d377c4afdd3666685eaf34dbff9d660a181fda5a.json.gz
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (9/9), 30.14 KiB | 10.05 MiB/s, done.
# Total 9 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/andrewkemmer/sports_prediction_hub.git
#    0861bb3..e6d5bfb  main -> main
# ...

# %%
# 1. Step to the repository root directory and clean out tracking blocks
# %cd /content/sports_prediction_hub

# 2. Force a pull configuration to cleanly integrate your AI agent's edits
print("🔄 Synchronizing local Colab workspace with GitHub...")
# !git config --global pull.rebase false
# !git pull origin main --force

# 3. Move precisely to your nested backend script directory
# %cd /content/sports_prediction_hub/mlb_streamlit

# 4. Compile your point-in-time metrics, calibration curves, and game matrices
print("📦 Compiling calibration curves, model states, and games into a single dashboard payload...")
# !python3 scripts/export_dashboard_payload.py

# 5. Step back to root to execute an uninhibited global staging operation
# %cd /content/sports_prediction_hub
print("🔒 Overriding ignore constraints to stage true dashboard asset array...")
# !git add -f mlb_streamlit/cache/dashboard_payload.json 2>/dev/null || true
# !git add .

# 6. Commit and sync the unified payload to your dashboard project tracking branch
print("📤 Pushing consolidated JSON payload live...")
# !git commit -m "automation: sync consolidated model payload and update v13 matrix asset"
# !git push origin main

print("🏁 Success! The dashboard payload is live and tracked in your project.")
# Out:
# /content/sports_prediction_hub
# 🔄 Synchronizing local Colab workspace with GitHub...
# remote: Enumerating objects: 41, done.
# remote: Counting objects: 100% (41/41), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 26 (delta 17), reused 23 (delta 14), pack-reused 0 (from 0)
# Unpacking objects: 100% (26/26), 9.26 KiB | 790.00 KiB/s, done.
# From https://github.com/andrewkemmer/sports_prediction_hub
#  * branch            main       -> FETCH_HEAD
#    e6d5bfb..90ece43  main       -> origin/main
# Updating e6d5bfb..90ece43
# Fast-forward
#  isolate/assets/charts-Bccv-aQG.js                 |  61 -----
#  isolate/assets/radix-ui-BoTfRgM1.js               |  50 ----
#  isolate/index.html                                |   8 +-
#  mlb_streamlit/scripts/export_dashboard_payload.py | 175 ++++++++++++++
#  src/components/mlb/CalibrationTab.tsx             | 276 +++++++++++++++-------
#  src/components/mlb/ModelMonitorTab.tsx            |  21 +-
# ...
